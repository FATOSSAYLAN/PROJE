# %% [markdown]
# <a href="https://colab.research.google.com/github/FATOSSAYLAN/PROJE/blob/main/reportmachine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
from sklearn.preprocessing import MinMaxScaler

# %%
dosya ='VAKKO-Geçmiş-Verileri-full.xls'

# %%
data.head()
# Out:
#    Tarih  Şimdi  Açılış  Yüksek  Düşük  Hac.  Fark %
# 0    870    652     654     651    653   494     318
# 1    775    651     657     650    594   275      75
# 2    739    653     660     652    656   280     105
# 3    708    658     668     653    658   200     102
# 4    675    663     667     659    657   295      46

# %%
dataset_train = pd.read_csv('VAKKO Geçmiş Verileri full.csv')
training_set = dataset_train.iloc[:, 1:2].values

# %%
dataset_train.head()
# Out:
#         Tarih   Şimdi  Açılış  Yüksek   Düşük     Hac.  Fark %
# 0  27.11.2023  80,600  80,600  82,750  80,000  613,99K   0,19%
# 1  24.11.2023  80,450  81,850  82,500  79,000  309,02K  -1,05%
# 2  23.11.2023  81,300  82,550  83,600  81,300  323,16K  -1,51%
# 3  22.11.2023  82,550  84,400  84,400  82,100  262,76K  -1,43%
# 4  21.11.2023  83,750  84,350  85,500  82,000  351,17K  -0,71%

# %%
data=pd.read_csv('VAKKO Geçmiş Verileri full.csv')
data
# Out:
#           Tarih   Şimdi  Açılış  Yüksek   Düşük     Hac.  Fark %
# 0    27.11.2023  80,600  80,600  82,750  80,000  613,99K   0,19%
# 1    24.11.2023  80,450  81,850  82,500  79,000  309,02K  -1,05%
# 2    23.11.2023  81,300  82,550  83,600  81,300  323,16K  -1,51%
# 3    22.11.2023  82,550  84,400  84,400  82,100  262,76K  -1,43%
# 4    21.11.2023  83,750  84,350  85,500  82,000  351,17K  -0,71%
# ..          ...     ...     ...     ...     ...      ...     ...
# 973  08.01.2020   3,690   3,647   3,750   3,588    2,16M  -0,46%
# 974  07.01.2020   3,707   3,690   3,775   3,656    2,07M   3,32%
# 975  06.01.2020   3,588   3,758   3,878   3,571    2,44M  -6,22%
# 976  03.01.2020   3,826   3,929   3,997   3,750    3,28M  -3,46%
# 977  02.01.2020   3,963   3,869   3,997   3,869    2,89M   2,43%
#
# [978 rows x 7 columns]

# %%
data.shape
# Out:
# (978, 7)

# %%
data.columns
# Out:
# Index(['Tarih', 'Şimdi', 'Açılış', 'Yüksek', 'Düşük', 'Hac.', 'Fark %'], dtype='object')

# %%
data.isna().sum()
# Out:
# Tarih     0
# Şimdi     0
# Açılış    0
# Yüksek    0
# Düşük     0
# Hac.      0
# Fark %    0
# dtype: int64

# %%
dataset_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 978 entries, 0 to 977
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tarih   978 non-null    object
#  1   Şimdi   978 non-null    object
#  2   Açılış  978 non-null    object
#  3   Yüksek  978 non-null    object
#  4   Düşük   978 non-null    object
#  5   Hac.    978 non-null    object
#  6   Fark %  978 non-null    object
# dtypes: object(7)
# memory usage: 53.6+ KB

# %%
length_data = len(data)     # rows that data has
split_ratio = 0.7           # %70 train + %30 validation
length_train = round(length_data * split_ratio)
length_validation = length_data - length_train
print("Data length :", length_data)
print("Train data length :", length_train)
print("Validation data lenth :", length_validation)
# Out:
# Data length : 978
# Train data length : 685
# Validation data lenth : 293

# %%
validation_data = data[length_train:].iloc[:,:2]
validation_data['Tarih'] = pd.to_datetime(validation_data['Tarih'])
validation_data
# Out:
#                             Tarih  Şimdi
# 685 1970-01-01 00:00:00.000000003    581
# 686 1970-01-01 00:00:00.000000813    549
# 687 1970-01-01 00:00:00.000000782    546
# 688 1970-01-01 00:00:00.000000747    467
# 689 1970-01-01 00:00:00.000000714    483
# ..                            ...    ...
# 973 1970-01-01 00:00:00.000000227    256
# 974 1970-01-01 00:00:00.000000192    258
# 975 1970-01-01 00:00:00.000000158    254
# 976 1970-01-01 00:00:00.000000063    262
# 977 1970-01-01 00:00:00.000000030    274
#
# [293 rows x 2 columns]

# %%
dataset_train = train_data.Şimdi.values
dataset_train.shape
# Out:
# (685,)

# %%
dataset_train = np.reshape(dataset_train, (-1,1))
dataset_train.shape
# Out:
# (685, 1)

# %%
scaler = MinMaxScaler(feature_range = (0,1))



dataset_train_scaled = scaler.fit_transform(dataset_train)

dataset_train_scaled.shape
# Out:
# (685, 1)

# %%
plt.subplots(figsize=(15, 6))
plt.plot(dataset_train_scaled, label='Normalized Şimdi TL')
plt.xlabel("Gün")
plt.ylabel("Normalleştirilmiş Şimdi TL")
plt.legend()
plt.show()

# %%
data = df.filter(['Close'])
df = np.array(data).reshape(-1,1)
df
# Out:
# array([[  1.125     ],
#        [  1.03750002],
#        [  1.07500005],
#        ...,
#        [400.25      ],
#        [402.5       ],
#        [396.        ]])

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_df = scaler.fit_transform(np.array(df).reshape(-1,1))
scaled_df
# Out:
# array([[4.96023166e-04],
#        [3.74618934e-04],
#        [4.26649366e-04],
#        ...,
#        [5.54272910e-01],
#        [5.57394734e-01],
#        [5.48376131e-01]])

# %%
X_train = []
y_train = []

time_step = 50

for i in range(time_step, length_train):
    X_train.append(dataset_train_scaled[i-time_step:i,0])
    y_train.append(dataset_train_scaled[i,0])

# convert list to array
X_train, y_train = np.array(X_train), np.array(y_train)
print("Shape of X_train before reshape :",X_train.shape)
print("Shape of y_train before reshape :",y_train.shape)
# Out:
# Shape of X_train before reshape : (635, 50)
# Shape of y_train before reshape : (635,)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1],1))
y_train = np.reshape(y_train, (y_train.shape[0],1))

print("Shape of X_train after reshape :",X_train.shape)
print("Shape of y_train after reshape :",y_train.shape)
# Out:
# Shape of X_train after reshape : (635, 50, 1)
# Shape of y_train after reshape : (635, 1)

# %%
# Compiling the RNN
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to Training Data Set
regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1031
# Epoch 2/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1031
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1031
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1031
# Epoch 5/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1031
# Epoch 6/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1031
# Epoch 7/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1031
# Epoch 8/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1031
# Epoch 9/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1031
# Epoch 10/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1031
# Epoch 11/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1031
# Epoch 12/100
# ...
